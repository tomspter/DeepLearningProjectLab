# %%
# !python train.py --config config.json --input_wavs_dir ../DataSet/LJSpeech-1.1/wavs --input_training_file ../DataSet/LJSpeech-1.1/training.txt --input_validation_file ../DataSet/LJSpeech-1.1/validation.txt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /root/miniconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# Initializing Training Process..
# Batch size per GPU : 16
# Generator(
#   (linear): Linear(in_features=256, out_features=513, bias=True)
#   (decs): ModuleList(
#     (0): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (1): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (2): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (3): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (4): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (5): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (6): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (7): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (8): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (9): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (10): ResBlock(
#       (convs): ModuleList(
#         (0): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#   )
#   (conv_post): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (reflection_pad): ReflectionPad1d((1, 0))
#   (stft): TorchSTFT()
# )
# checkpoints directory :  cp_autovocoder
# Epoch: 1
# Steps : 0, Gen Loss Total : 317.117, Mel-Spec. Error : 4.846, Wav. Error : 0.879, s/b : 2.011
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# Steps : 50, Gen Loss Total : 129.319, Mel-Spec. Error : 2.536, Wav. Error : 0.037, s/b : 0.216
# Steps : 100, Gen Loss Total : 99.709, Mel-Spec. Error : 1.939, Wav. Error : 0.021, s/b : 0.215
# Steps : 150, Gen Loss Total : 109.091, Mel-Spec. Error : 2.053, Wav. Error : 0.015, s/b : 0.220
# Steps : 200, Gen Loss Total : 92.981, Mel-Spec. Error : 1.631, Wav. Error : 0.013, s/b : 0.215
# Steps : 250, Gen Loss Total : 95.090, Mel-Spec. Error : 1.698, Wav. Error : 0.013, s/b : 0.214
# Steps : 300, Gen Loss Total : 86.557, Mel-Spec. Error : 1.470, Wav. Error : 0.014, s/b : 0.217
# Steps : 350, Gen Loss Total : 80.367, Mel-Spec. Error : 1.310, Wav. Error : 0.011, s/b : 0.214
# Steps : 400, Gen Loss Total : 82.807, Mel-Spec. Error : 1.338, Wav. Error : 0.012, s/b : 0.218
# Steps : 450, Gen Loss Total : 80.904, Mel-Spec. Error : 1.325, Wav. Error : 0.012, s/b : 0.213
# Steps : 500, Gen Loss Total : 79.631, Mel-Spec. Error : 1.369, Wav. Error : 0.016, s/b : 0.214
# Steps : 550, Gen Loss Total : 77.644, Mel-Spec. Error : 1.285, Wav. Error : 0.014, s/b : 0.216
# Steps : 600, Gen Loss Total : 72.317, Mel-Spec. Error : 1.165, Wav. Error : 0.018, s/b : 0.214
# Steps : 650, Gen Loss Total : 75.622, Mel-Spec. Error : 1.231, Wav. Error : 0.014, s/b : 0.214
# Steps : 700, Gen Loss Total : 72.242, Mel-Spec. Error : 1.092, Wav. Error : 0.022, s/b : 0.217
# Steps : 750, Gen Loss Total : 69.633, Mel-Spec. Error : 1.107, Wav. Error : 0.018, s/b : 0.215
# Steps : 800, Gen Loss Total : 72.500, Mel-Spec. Error : 1.164, Wav. Error : 0.015, s/b : 0.218
# Time taken for epoch 1 is 189 sec
#
# Epoch: 2
# Steps : 850, Gen Loss Total : 70.279, Mel-Spec. Error : 1.075, Wav. Error : 0.017, s/b : 0.217
# Steps : 900, Gen Loss Total : 70.825, Mel-Spec. Error : 1.102, Wav. Error : 0.018, s/b : 0.214
# Steps : 950, Gen Loss Total : 66.044, Mel-Spec. Error : 1.024, Wav. Error : 0.012, s/b : 0.214
# Steps : 1000, Gen Loss Total : 66.883, Mel-Spec. Error : 0.982, Wav. Error : 0.019, s/b : 0.214
# Steps : 1050, Gen Loss Total : 62.179, Mel-Spec. Error : 0.926, Wav. Error : 0.013, s/b : 0.220
# Steps : 1100, Gen Loss Total : 60.984, Mel-Spec. Error : 0.923, Wav. Error : 0.011, s/b : 0.215
# Steps : 1150, Gen Loss Total : 63.958, Mel-Spec. Error : 0.951, Wav. Error : 0.015, s/b : 0.214
# Steps : 1200, Gen Loss Total : 59.211, Mel-Spec. Error : 0.862, Wav. Error : 0.015, s/b : 0.216
# Steps : 1250, Gen Loss Total : 60.441, Mel-Spec. Error : 0.873, Wav. Error : 0.016, s/b : 0.214
# Steps : 1300, Gen Loss Total : 58.865, Mel-Spec. Error : 0.827, Wav. Error : 0.016, s/b : 0.219
# Steps : 1350, Gen Loss Total : 61.239, Mel-Spec. Error : 0.829, Wav. Error : 0.024, s/b : 0.213
# Steps : 1400, Gen Loss Total : 59.883, Mel-Spec. Error : 0.805, Wav. Error : 0.020, s/b : 0.214
# Steps : 1450, Gen Loss Total : 55.059, Mel-Spec. Error : 0.793, Wav. Error : 0.013, s/b : 0.214
# Steps : 1500, Gen Loss Total : 56.855, Mel-Spec. Error : 0.779, Wav. Error : 0.014, s/b : 0.214
# Steps : 1550, Gen Loss Total : 57.719, Mel-Spec. Error : 0.774, Wav. Error : 0.021, s/b : 0.213
# Steps : 1600, Gen Loss Total : 58.564, Mel-Spec. Error : 0.811, Wav. Error : 0.015, s/b : 0.214
# Time taken for epoch 2 is 171 sec
#
# Epoch: 3
# Steps : 1650, Gen Loss Total : 55.058, Mel-Spec. Error : 0.740, Wav. Error : 0.017, s/b : 0.216
# Steps : 1700, Gen Loss Total : 58.054, Mel-Spec. Error : 0.762, Wav. Error : 0.014, s/b : 0.216
# Steps : 1750, Gen Loss Total : 53.641, Mel-Spec. Error : 0.756, Wav. Error : 0.012, s/b : 0.216
# Steps : 1800, Gen Loss Total : 55.027, Mel-Spec. Error : 0.715, Wav. Error : 0.017, s/b : 0.214
# Steps : 1850, Gen Loss Total : 50.743, Mel-Spec. Error : 0.669, Wav. Error : 0.017, s/b : 0.214
# Steps : 1900, Gen Loss Total : 51.489, Mel-Spec. Error : 0.723, Wav. Error : 0.012, s/b : 0.214
# Steps : 1950, Gen Loss Total : 55.384, Mel-Spec. Error : 0.727, Wav. Error : 0.018, s/b : 0.216
# Steps : 2000, Gen Loss Total : 53.183, Mel-Spec. Error : 0.676, Wav. Error : 0.015, s/b : 0.219
# Saving checkpoint to cp_autovocoder/e_00002000
# Complete.
# Saving checkpoint to cp_autovocoder/g_00002000
# Complete.
# Saving checkpoint to cp_autovocoder/do_00002000
# Complete.
# Steps : 2050, Gen Loss Total : 52.258, Mel-Spec. Error : 0.714, Wav. Error : 0.013, s/b : 0.215
# ^C
# Traceback (most recent call last):
#   File "train.py", line 296, in <module>
#     main()
#   File "train.py", line 292, in main
#     train(0, a, h)
#   File "train.py", line 146, in train
#     loss_disc_s, losses_disc_s_r, losses_disc_s_g = discriminator_loss(y_ds_hat_r, y_ds_hat_g)
#   File "/root/autodl-tmp/DP_Group/Autovocoder/models.py", line 260, in discriminator_loss
#     r_losses.append(r_loss.item())
# KeyboardInterrupt
